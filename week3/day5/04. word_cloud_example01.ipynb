# %% [markdown]
# # Wordcloud 만들어보기
# - KoNLPy 라이브러리로 한국어 문장을 전처리
# - Counter를 이용하여 빈도수 측정
# - WordCloud를 이용해 시각화

# %%
# %pip install wordcloud
# %pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 12.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 45.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 40.1 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 필요 라이브러리
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from konlpy.tag import Hannanum

from collections import Counter

# %%
national_anthem = """
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
남산 위에 저 소나무 철갑을 두른 듯
바람 서리 불변함은 우리 기상일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
가을 하늘 공활한데 높고 구름 없이
밝은 달은 우리 가슴 일편단심일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
이 기상과 이 맘으로 충성을 다하여
괴로우나 즐거우나 나라 사랑하세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
"""

# %%
hannanum = Hannanum()
nouns = hannanum.nouns(national_anthem)
print(nouns)
# Out:
# ['동해물', '백두산', '하느님', '보우하사', '우리나라', '무궁화', '삼천리', '화', '강산', '사람', '대한', '길', '보전하세', '남산', '위', '소나무', '철갑', '듯', '불변', '우리', '기상일세', '무궁화', '삼천리', '화', '강산', '사람', '대한', '길', '보전하세', '하늘', '공활한데', '구름', '달', '우리', '가슴', '일편단심일세', '무궁화', '삼천리', '화', '강산', '사람', '대한', '길', '보전하세', '기상', '충성', '사랑하세', '무궁화', '삼천리', '화', '강산', '사람', '대한', '길', '보전하세']

# %%
# 각 단어의 개수 세기
counter = Counter(nouns)
print(counter)
# Out:
# Counter({'무궁화': 4, '삼천리': 4, '화': 4, '강산': 4, '사람': 4, '대한': 4, '길': 4, '보전하세': 4, '우리': 2, '동해물': 1, '백두산': 1, '하느님': 1, '보우하사': 1, '우리나라': 1, '남산': 1, '위': 1, '소나무': 1, '철갑': 1, '듯': 1, '불변': 1, '기상일세': 1, '하늘': 1, '공활한데': 1, '구름': 1, '달': 1, '가슴': 1, '일편단심일세': 1, '기상': 1, '충성': 1, '사랑하세': 1})

# %% [markdown]
# 폰트 출처: [여주도자체](https://gongu.copyright.or.kr/gongu/wrt/wrt/view.do?wrtSn=13371586&menuNo=200023)

# %%
wordColud = WordCloud(
    font_path="font/YeojuCeramic-TTF.ttf",
    background_color="white",
    width=1000,
    height=1000,
)
img = wordColud.generate_from_frequencies(counter)
plt.imshow(img)
